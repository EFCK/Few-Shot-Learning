# %%
import tensorflow as tf
import keras
import cv2
import numpy as np 
from keras.layers import MaxPool2D, Conv2D, Flatten, Dense
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 import keras
#       3 from keras.layers import MaxPool2D, Conv2D, Flatten, Dense
#
# File c:\Users\krbyk\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:51
#      49 from tensorflow._api.v2 import autograph
#      50 from tensorflow._api.v2 import bitwise
# ---> 51 from tensorflow._api.v2 import compat
#      52 from tensorflow._api.v2 import config
#      53 from tensorflow._api.v2 import data
#
# File c:\Users\krbyk\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\compat\__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
# ...
